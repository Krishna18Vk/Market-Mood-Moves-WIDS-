# %%
from src.nlp_pipeline import preprocess_text, get_vader_score, get_finbert_score

headline = "Apple reports record profits"
tokens = preprocess_text(headline)
vader = get_vader_score(headline)
finbert = get_finbert_score(headline)
print(f"Tokens: {tokens}\nVADER: {vader}\nFinBERT: {finbert}")
